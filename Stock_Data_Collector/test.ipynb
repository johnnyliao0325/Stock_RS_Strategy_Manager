# %%
import pandas as pd
import datetime
n_day_ago = 0
a = datetime.datetime.strptime(str(datetime.date.today() - datetime.timedelta(days=n_day_ago)), '%Y-%m-%d')
print(a)
print(a.weekday())
for y_i in range(10):
    try:
        d = datetime.datetime.strptime(str(datetime.date.today() - datetime.timedelta(days=y_i+1+n_day_ago)), '%Y-%m-%d')
        d = str(d).split(' ')[0]
        
        yesterday_allstock_info = pd.read_excel(fr'C:\Users\User\Desktop\StockInfoHub\Stock_Data_Collector\全個股條件篩選\{d}選股.xlsx')
        
        break
    except:
        continue
yesterday_allstock_info.set_index('ID', inplace=True)
print(yesterday_allstock_info.loc[2330, 'ES20rate'])
# Out:
# 2024-05-04 00:00:00
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 17>()
#      15     except:
#      16         continue
# ---> 17 yesterday_allstock_info.set_index('ID', inplace=True)
#      18 print(yesterday_allstock_info.loc[2330, 'ES20rate'])
#
# NameError: name 'yesterday_allstock_info' is not defined

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].astype(str)
df = df.sort_values(by = ['Unnamed: 0'], ascending = False)
# df.head()
df.to_excel(r'C:\Users\User\Desktop\StockInfoHub\Stock_RS_rate_analysis\100產業分析\100產業實質成交值排行.xlsx', index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
uptrend_data = [
    [61, 62, 60, 61.5], [61.5, 63, 61, 62], [62, 64, 61.5, 63.5], [63.5, 65, 62.5, 64],
    [64, 66, 63, 65.5], [65.5, 67, 64, 66], [66, 68, 65, 67.5], [67.5, 69, 66, 68],
    [68, 70, 67, 69.5], [69.5, 71, 68, 70], [70, 72, 69, 71.5], [71.5, 73, 70, 72],
    [72, 74, 71, 73.5], [73.5, 75, 72, 74], [74, 76, 73, 75.5], [75.5, 77, 74, 76],
    [76, 78, 75, 77.5], [77.5, 79, 76, 78], [78, 80, 77, 79.5], [79.5, 81, 78, 80],
    [80, 82, 79, 81.5], [81.5, 83, 80, 82], [82, 84, 81, 83.5], [83.5, 85, 82, 84],
    [84, 86, 83, 85.5], [85.5, 87, 84, 86], [86, 88, 85, 87.5], [87.5, 89, 86, 88],
    [88, 90, 87, 89.5], [89.5, 91, 88, 90]
]

consolidation_data = [
    [61, 62, 60, 61], [61, 61.5, 60.5, 61], [61, 61.5, 60, 60.5], [60.5, 61, 59.5, 60],
    [60, 60.5, 59, 59.5], [59.5, 60, 58.5, 59], [59, 59.5, 58, 58.5], [58.5, 59, 57.5, 58],
    [58, 58.5, 57, 57.5], [57.5, 58, 56.5, 57], [57, 57.5, 56, 56.5], [56.5, 57, 55.5, 56],
    [56, 56.5, 55, 55.5], [55.5, 56, 54.5, 55], [55, 55.5, 54, 54.5], [54.5, 55, 53.5, 54],
    [54, 54.5, 53, 53.5], [53.5, 54, 52.5, 53], [53, 53.5, 52, 52.5], [52.5, 53, 51.5, 52],
    [52, 52.5, 51, 51.5], [51.5, 52, 50.5, 51], [51, 51.5, 50, 50.5], [50.5, 51, 49.5, 50],
    [50, 50.5, 49, 49.5], [49.5, 50, 48.5, 49], [49, 49.5, 48, 48.5], [48.5, 49, 47.5, 48],
    [48, 48.5, 47, 47.5], [47.5, 48, 46.5, 47]
]

plt.figure(figsize=(20, 10))
plt.plot(list(map(lambda x: x[0], consolidation_data)), label='open')
plt.show()
